# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Administrator/Downloads/winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.drop_duplicates().shape
# Out:
# (1359, 12)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(15,7))
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0E8C9820>,
# ...
#       dtype=object)

# %% [markdown]
# ### We see the above Histogram, only "PH" Column is followed by approximately normally distributes while others are not normally distribbution

# %%
plt.figure(figsize=(15,7))
df.boxplot()

# %%
df["pH"].describe()
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
df.boxplot(column="pH")

# %%
upper_bound=df["pH"].mean() + 3 * df["pH"].std()
lower_bound=df["pH"].mean() - 3 * df["pH"].std()
print(upper_bound)
print(lower_bound)
print(df["pH"].mean())
# Out:
# 3.774272590457971
# 2.847953801036715
# 3.311113195747343

# %%
fig=df.hist(column="density")

# %%
df.boxplot(column="density")

# %%
df["density"].describe()
# Out:
# count    1599.000000
# mean        0.996747
# std         0.001887
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997835
# max         1.003690
# Name: density, dtype: float64

# %%
upper_den=df["density"].mean() + 3 * df["density"].std()
lower_den=df["density"].mean() - 3 * df["density"].std()
print(upper_den)
print(lower_den)
print(df["density"].mean())
# Out:
# 1.002408681036011
# 0.9910846773129557
# 0.9967466791744833

# %% [markdown]
# ## If the features are skewed then we used IQR method

# %%
fig=df.hist(column="fixed acidity")

# %%
df.boxplot(column="fixed acidity")

# %%
df["fixed acidity"].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %% [raw]
# #### Lets compute the Interquantile range to calculate the boundaries
# IQR=df.Fare.quantile(0.75)-df.Fare.quantile(0.25)
#
# lower_bridge=df['Fare'].quantile(0.25)-(IQR*1.5)
# upper_bridge=df['Fare'].quantile(0.75)+(IQR*1.5)
# print(lower_bridge), print(upper_bridge)

# %%
IQR=df["fixed acidity"].quantile(0.75)-df["fixed acidity"].quantile(0.25)

# %%
lower_fa=df["fixed acidity"].quantile(0.25)-(IQR*1.5)
upper_fa=df["fixed acidity"].quantile(0.25)+(IQR*1.5)
print(lower_fa),print(upper_fa)
# Out:
# 3.95
# 10.25
# (None, None)

# %%
## Extreme outlier
lower_Efa=df["fixed acidity"].quantile(0.25)-(IQR*3)
upper_Efa=df["fixed acidity"].quantile(0.25)+(IQR*3)
print(lower_Efa),print(upper_Efa)
# Out:
# 0.8000000000000007
# 13.399999999999999
# (None, None)

# %%
fig=df.hist(column="volatile acidity")

# %%
df.boxplot(column="volatile acidity")

# %%
df["volatile acidity"].describe()
# Out:
# count    1599.000000
# mean        0.527821
# std         0.179060
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
IQR=df["volatile acidity"].quantile(0.75)-df["volatile acidity"].quantile(0.25)
lower_va=df["volatile acidity"].quantile(0.25)-(IQR*1.5)
upper_va=df['volatile acidity'].quantile(0.75)+(IQR*1.5)
print(lower_va),print(upper_va)
# Out:
# 0.015000000000000013
# 1.0150000000000001
# (None, None)

# %%
fig=df.hist(column="citric acid")

# %%
df.boxplot(column="citric acid")

# %%
df["citric acid"].describe()
# Out:
# count    1599.000000
# mean        0.270976
# std         0.194801
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
IQR=df["citric acid"].quantile(0.75)-df["citric acid"].quantile(0.25)
lower_ca=df["citric acid"].quantile(0.25)-(IQR*1.5)
upper_ca=df["citric acid"].quantile(0.75)+(IQR*1.5)
print(lower_ca),print(upper_ca)
# Out:
# -0.4049999999999999
# 0.9149999999999999
# (None, None)

# %%
fig=df.hist(column="residual sugar")

# %%
df.boxplot(column="residual sugar")

# %%
df["residual sugar"].describe()
# Out:
# count    1599.000000
# mean        2.538806
# std         1.409928
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
IQR=df["residual sugar"].quantile(0.75)-df["residual sugar"].quantile(0.25)
lower_rs=df["residual sugar"].quantile(0.25)-(IQR*1.5)
upper_rs=df["residual sugar"].quantile(0.75)+(IQR*1.5)
print(lower_rs),print(upper_rs)
# Out:
# 0.8499999999999996
# 3.6500000000000004
# (None, None)

# %%
fig=df.hist(column="chlorides")

# %%
df.boxplot(column="chlorides")

# %%
df["chlorides"].describe()
# Out:
# count    1599.000000
# mean        0.087467
# std         0.047065
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
IQR=df["chlorides"].quantile(0.75)-df["chlorides"].quantile(0.25)
lower_cl=df["chlorides"].quantile(0.25)-(IQR*1.5)
upper_cl=df["chlorides"].quantile(0.75)+(IQR*1.5)
print(lower_cl),print(upper_cl)
# Out:
# 0.04000000000000002
# 0.11999999999999998
# (None, None)

# %%
fig=df.hist(column="free sulfur dioxide")

# %%
df.boxplot(column="free sulfur dioxide")

# %%
df["free sulfur dioxide"].describe()
# Out:
# count    1599.000000
# mean       15.874922
# std        10.460157
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
IQR=df["free sulfur dioxide"].quantile(0.75)-df["free sulfur dioxide"].quantile(0.25)
lower_fsd=df["free sulfur dioxide"].quantile(0.25)-(IQR*1.5)
upper_fsd=df["free sulfur dioxide"].quantile(0.75)+(IQR*1.5)
print(lower_fsd),print(upper_fsd)
# Out:
# -14.0
# 42.0
# (None, None)

# %%
fig=df.hist(column="total sulfur dioxide")

# %%
df.boxplot(column="total sulfur dioxide")

# %%
df["total sulfur dioxide"].describe()
# Out:
# count    1599.000000
# mean       46.467792
# std        32.895324
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
IQR=df["total sulfur dioxide"].quantile(0.75)-df["total sulfur dioxide"].quantile(0.25)
lower_tsd=df["total sulfur dioxide"].quantile(0.25)-(IQR*1.5)
upper_tsd=df["total sulfur dioxide"].quantile(0.75)+(IQR*1.5)
print(lower_tsd),print(upper_tsd)
# Out:
# -38.0
# 122.0
# (None, None)

# %%
fig=df.hist(column="sulphates")

# %%
df.boxplot(column="sulphates")

# %%
df["sulphates"].describe()
# Out:
# count    1599.000000
# mean        0.658149
# std         0.169507
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
IQR=df["sulphates"].quantile(0.75)-df["sulphates"].quantile(0.25)
lower_sul=df["sulphates"].quantile(0.25)-(IQR*1.5)
upper_sul=df["sulphates"].quantile(0.75)+(IQR*1.5)
print(lower_sul),print(upper_sul)
# Out:
# 0.28000000000000014
# 0.9999999999999999
# (None, None)

# %%
fig=df.hist(column="alcohol")

# %%
df.boxplot(column="alcohol")

# %%
df["alcohol"].describe()
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
IQR=df["alcohol"].quantile(0.75)-df["alcohol"].quantile(0.25)
lower_al=df["alcohol"].quantile(0.25)-(IQR*1.5)
upper_al=df["alcohol"].quantile(0.75)+(IQR*1.5)
print(lower_al),print(upper_al)
# Out:
# 7.1000000000000005
# 13.5
# (None, None)

# %%
fig=df.hist(column="quality")

# %%
df.boxplot(column="quality")

# %%
df["quality"].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
IQR=df["quality"].quantile(0.75)-df["quality"].quantile(0.25)
lower_qu=df["quality"].quantile(0.25)-(IQR*1.5)
upper_qu=df["quality"].quantile(0.75)+(IQR*1.5)
print(lower_qu),print(upper_qu)
# Out:
# 3.5
# 7.5
# (None, None)

# %%
data=df.copy()

# %%
data.loc[data["quality"]>=7.5,"quality"]=7.5
data.loc[data["quality"]<=3.5,"quality"]=3.5

# %%
data.loc[data["fixed acidity"]>=10.25,"fixed acidity"]=10.25
data.loc[data["fixed acidity"]<=3.95,"fixed acidity"]=3.95

# %%
data.loc[data["volatile acidity"]>=1.015,"volatile acidity"]=1.015    
data.loc[data["volatile acidity"]<=0.015,"volatile acidity"]=0.015    #0.015000000000000013

# %%
data.loc[data["citric acid"]>=0.92,"citric acid"]=0.92
#data.loc[data["citric acid"]<=3.95,"citric acid"]=3.95

# %%
data.loc[data["residual sugar"]>=3.65,"residual sugar"]=3.65
data.loc[data["residual sugar"]<=0.85,"residual sugar"]=0.84    #

# %%
data.loc[data["total sulfur dioxide"]>=122.0,"total sulfur dioxide"]=122.0
#data.loc[data["total sulfur dioxide"]<=3.5,"total sulfur dioxide"]=3.5

# %%
data.loc[data["free sulfur dioxide"]>=42.0,"free sulfur dioxide"]=42.0
#data.loc[data["free sulfur dioxide"]<=3.5,"free sulfur dioxide"]=3.5

# %%
data.loc[data["chlorides"]>=0.12,"chlorides"]=0.12
data.loc[data["chlorides"]<=0.04,"chlorides"]=0.04

# %%
data.loc[data["alcohol"]>=13.5,"alcohol"]=13.5
data.loc[data["alcohol"]<=7.1,"alcohol"]=7.1

# %%
data.loc[data["pH"]>=3.77,"pH"]=3.77
data.loc[data["pH"]<=2.85,"pH"]=2.85

# %%
data.loc[data["density"]>=1.0,"density"]=1.0
data.loc[data["density"]<=0.99,"density"]=0.99

# %%
plt.figure(figsize=(30,15))
data.boxplot()

# %%
sns.pairplot(x_vars=["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","quality"],y_vars=["alcohol"],data=df)

# %%
y=df["alcohol"]
x=df.drop("alcohol",axis=1)

# %%
from sklearn.model_selection import  train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(ytest,ypred)
mae
# Out:
# 0.45348453333802574

# %%
mse=mean_squared_error(ytest,ypred)
mse
# Out:
# 0.37538149378490204

# %%
r2_score(ytest,ypred)
# Out:
# 0.702260779485905

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg=PolynomialFeatures(degree=5)

# %%
x_poly=poly_reg.fit_transform(x)

# %%
pl_reg=LinearRegression()

# %%
pl_reg.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
pl_reg.score(x_poly,y)
# Out:
# 0.9999686773583305

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def get_vif(df):
    d={}
    for i in range(df.shape[1]):
        d[df.columns[i]]=variance_inflation_factor(df.values,i)
    return d

# %%
X=df
get_vif(X)
# Out:
# {'fixed acidity': 74.45531208183216,
#  'volatile acidity': 17.960867041828163,
#  'citric acid': 9.19254901808645,
#  'residual sugar': 4.664003138646322,
#  'chlorides': 6.641291238334234,
#  'free sulfur dioxide': 6.460602792739823,
#  'total sulfur dioxide': 6.605273810174638,
#  'density': 1528.154301613075,
#  'pH': 1078.1710892657966,
#  'sulphates': 22.462103065126183,
#  'alcohol': 147.61634505512268,
#  'quality': 77.72825937492063}

# %%
X=df.drop(columns=["density"])
get_vif(X)
# Out:
# {'fixed acidity': 41.427951990373046,
#  'volatile acidity': 17.942014582881775,
#  'citric acid': 9.165110816864289,
#  'residual sugar': 4.663615272391166,
#  'chlorides': 6.042817089885267,
#  'free sulfur dioxide': 6.398388794661094,
#  'total sulfur dioxide': 6.125697680498969,
#  'pH': 165.6570629218086,
#  'sulphates': 22.46145847004757,
#  'alcohol': 147.17153301544428,
#  'quality': 75.24267655516535}

# %%
x=df.drop(columns=["density","alcohol"])
y=df["alcohol"]

# %%
from sklearn.linear_model import ElasticNet

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
alpha=[0.0001,0.001,0.01,0.1,0.3,0.5,1,10]

# %%
def get_best_alpha(alpha):
    for i in alpha:
        model=ElasticNet(alpha=i)
        model.fit(xtrain,ytrain)
        ypred=model.predict(xtest)
        mse=mean_squared_error(ytest,ypred)
        rmse=np.sqrt(mse)
        mae=mean_absolute_error(ytest,ypred)
        scores[i]=model.score(xtest,ytest)
        print(" For Alpha = {} | R-square :{} MSE :{} RMSE :{} MAE:{} ".format(i,model.score(xtest,ytest),mse,rmse,mae))
    return max(scores, key= lambda x: scores[x])

# %%
print("Best Alpha is :",get_best_alpha(alpha))
# Out:
#  For Alpha = 0.0001 | R-square :0.38027441000812157 MSE :0.7257414989650909 RMSE :0.851904630205219 MAE:0.6582698755657049
#  For Alpha = 0.001 | R-square :0.3752935693920397 MSE :0.7315744075833533 RMSE :0.8553212306399002 MAE:0.6594250305102601
#  For Alpha = 0.01 | R-square :0.3357163496541975 MSE :0.7779220673238343 RMSE :0.8819989043779104 MAE:0.6861329218024332
#  For Alpha = 0.1 | R-square :0.25666074735174393 MSE :0.8705016416436919 RMSE :0.9330067747040703 MAE:0.7322735498860281
#  For Alpha = 0.3 | R-square :0.18905666249846742 MSE :0.9496706975450676 RMSE :0.9745104912442285 MAE:0.7743313695321583
#  For Alpha = 0.5 | R-square :0.12121362242941025 MSE :1.0291195865198017 RMSE :1.0144553151912614 MAE:0.8129351093639746
#  For Alpha = 1 | R-square :0.03357669244568917 MSE :1.1317484886632776 RMSE :1.0638366832664108 MAE:0.859388959147821
#  For Alpha = 10 | R-square :0.01752174323663569 MSE :1.1505499438443354 RMSE :1.072636911468338 MAE:0.8772296456747177
# ...

# %%
from sklearn.linear_model import ElasticNetCV

# %%
model= ElasticNetCV(alphas=alpha,cv=5)
model.fit(xtrain,ytrain)
# Out:
# ElasticNetCV(alphas=[0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 1, 10], cv=5)

# %%
model.alpha_
# Out:
# 0.0001

# %%
model.intercept_
# Out:
# 2.9794265878495114

# %%
ypred=model.predict(xtest)

# %%
model.score(xtest,ytest)
# Out:
# 0.38027441000812146

# %%
mean_squared_error(ytest,ypred)
# Out:
# 0.725741498965091

# %%
mean_absolute_error(ytest,ypred)
# Out:
# 0.6582698755657049
